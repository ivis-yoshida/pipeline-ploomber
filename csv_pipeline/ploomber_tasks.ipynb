# %%
# %%sh
# ploomber plot
# Out:
# Plot saved at: pipeline.png
# 100%|██████████| 4/4 [00:00<00:00, 13808.41it/s]

# %%
from IPython.display import Image
Image('pipeline.png')

# %%
# %%sh
# ploomber build
# Out:
# ...
# Executing:  50%|█████     | 4/8 [00:01<00:01,  2.36cell/s]@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @         WARNING: UNPROTECTED PRIVATE KEY FILE!          @
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Permissions 0644 for '/home/jovyan/.ssh/id_rsa' are too open.
# It is required that your private key files are NOT accessible by others.
# This private key will be ignored.
# Load key "/home/jovyan/.ssh/id_rsa": bad permissions
# root@dg02.dg.rcos.nii.ac.jp: Permission denied (publickey).
#
# ...
# Building task 'datalad_push': 100%|██████████| 1/1 [00:03<00:00,  3.73s/it]
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/io.py", line 20, in wrapper
#     fn(**kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/build.py", line 51, in main
#     report = dag.build(force=args.force, debug=args.debug)
# ...
