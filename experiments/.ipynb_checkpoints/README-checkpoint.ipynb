# %% [markdown]
# # experiments

# %% [markdown]
# ## 出力ディレクトリの初期化

# %%
# !rm -rf experiment1/output_data/*
# !rm -rf experiment2/output_data/*
# !rm -rf experiment3/output_data/*

# %% [markdown]
# ## 実験パイプラインの可視化

# %%
# %%sh
# ploomber plot
# Out:
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/spec/dagspec.py", line 778, in process_tasks
#     up = dag[task_name]
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/dag/dag.py", line 937, in __getitem__
#     return self._G.nodes[key]['task']
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
# KeyError: "DAG does not have a task with name 'code_A'"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/io.py", line 20, in wrapper
#     fn(**kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/plot.py", line 15, in main
#     dag, args = _custom_command(parser)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/parsers.py", line 389, in _custom_command
#     dag, args = load_dag_from_entry_point_and_parser(entry_point, parser,
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/parsers.py", line 435, in load_dag_from_entry_point_and_parser
#     dag, args = _process_file_dir_or_glob(parser)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/cli/parsers.py", line 376, in _process_file_dir_or_glob
#     dag = DAGSpec(dagspec_arg).to_dag()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/spec/dagspec.py", line 424, in to_dag
#     dag = self._to_dag()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/spec/dagspec.py", line 473, in _to_dag
#     process_tasks(dag, self, root_path=self._parent_path)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/ploomber/spec/dagspec.py", line 781, in process_tasks
#     raise KeyError('Error processing spec. Extracted '
# KeyError: "Error processing spec. Extracted a reference to a task with name 'code_A', but a task with such name doesn't exist. Loaded tasks: ['experiment1', 'experiment2', 'experiment3']"

# %%
from IPython.display import Image
Image('pipeline.png')

# %% [markdown]
# ## 実験再現のための環境構築

# %%
# !pip install -r experiment1/requirements.txt
# !pip install -r experiment2/requirements.txt
# !pip install -r experiment3/requirements.txt

# %% [markdown]
# ## 実験再現

# %%
# %%sh
# ploomber build
# Out:
# name    Ran?      Elapsed (s)    Percentage
# ------  ------  -------------  ------------
# code_A  True          2.09736       34.8861
# code_B  True          2.01404       33.5001
# code_C  True          1.90063       31.6137
# Building task 'code_A':   0%|          | 0/3 [00:00<?, ?it/s]
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Executing:  25%|██▌       | 1/4 [00:01<00:05,  1.72s/cell]
# Executing: 100%|██████████| 4/4 [00:02<00:00,  1.96cell/s]
# Building task 'code_B':  33%|███▎      | 1/3 [00:02<00:04,  2.10s/it]
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Executing:  25%|██▌       | 1/4 [00:01<00:04,  1.62s/cell]
# Executing: 100%|██████████| 4/4 [00:01<00:00,  2.04cell/s]
# Building task 'code_C':  67%|██████▋   | 2/3 [00:04<00:02,  2.05s/it]
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Executing:  25%|██▌       | 1/4 [00:01<00:04,  1.40s/cell]
# Executing: 100%|██████████| 4/4 [00:01<00:00,  2.29cell/s]
# Building task 'code_C': 100%|██████████| 3/3 [00:06<00:00,  2.01s/it]
